# %%
# Importing dependencies

import pandas as pd

# Clobbering any annoying pink warning boxes

import warnings
warnings.filterwarnings('ignore')

# %%
# Reading data into memory and instantiating dataframe

df = pd.read_csv('../../data/processed/solar_and_daylength_data.csv', index_col = 0)

# %%
# Resetting index...

df.reset_index(inplace = True)

# %%
# ...then setting it again -- what is my deal?!

df = df.set_index(pd.to_datetime(df['Date'])).drop('Date', axis = 1)

# %%
# Parsing columns

df = df[['Solar Energy (kWh)', 'Inverter 1 Energy (kWh)', 'Inverter 2 Energy (kWh)', 'Daylength in decimal hours']]

# %%
# Taking a peek

df
# Out:
#             Solar Energy (kWh)  Inverter 1 Energy (kWh)  \
# Date
# 2021-11-17                22.8                     10.9
# 2021-11-18                22.0                     10.6
# 2021-11-19                20.4                      9.9
# 2021-11-20                21.3                     10.2
# 2021-11-21                22.8                     10.8
# ...                        ...                      ...
# 2022-11-13                 0.0                      0.0
# 2022-11-14                 0.0                      0.0
# 2022-11-15                 0.0                      0.0
# 2022-11-16                 0.0                      0.0
# 2022-11-17                 0.0                      0.0
#
#             Inverter 2 Energy (kWh)  Daylength in decimal hours
# Date
# 2021-11-17                     11.8                        8.39
# 2021-11-18                     11.4                        8.37
# 2021-11-19                     10.5                        8.34
# 2021-11-20                     11.0                        8.32
# 2021-11-21                     12.0                        8.30
# ...                             ...                         ...
# 2022-11-13                      0.0                        8.50
# 2022-11-14                      0.0                        8.47
# 2022-11-15                      0.0                        8.45
# 2022-11-16                      0.0                        8.42
# 2022-11-17                      0.0                        8.40
#
# [366 rows x 4 columns]

# %%
# Resampling the data monthly isnt going to work, because each
# billing period is of varaied length (e.g., some bills are for 28 days,
# while some are for 32 days) of service

df.resample('M').sum()
# Out:
#             Solar Energy (kWh)  Inverter 1 Energy (kWh)  \
# Date
# 2021-11-30               299.4                    142.5
# 2021-12-31               473.0                    196.9
# 2022-01-31               459.1                    152.1
# 2022-02-28               880.4                    422.0
# 2022-03-31              1298.6                    620.2
# 2022-04-30              1451.0                    704.1
# 2022-05-31              1620.8                    790.5
# 2022-06-30              1536.0                    745.7
# 2022-07-31              1411.6                    685.9
# 2022-08-31              1254.6                    611.2
# 2022-09-30               703.6                    531.5
# 2022-10-31               505.5                    505.5
# 2022-11-30                57.9                     57.9
#
#             Inverter 2 Energy (kWh)  Daylength in decimal hours
# Date
# 2021-11-30                    156.9                      115.54
# 2021-12-31                    275.8                      248.11
# 2022-01-31                    307.3                      256.82
# 2022-02-28                    458.3                      254.34
# 2022-03-31                    678.4                      312.81
# 2022-04-30                    746.8                      334.16
# 2022-05-31                    831.0                      372.34
# 2022-06-30                    790.1                      372.93
# 2022-07-31                    725.5                      377.85
# 2022-08-31                    643.5                      353.61
# 2022-09-30                    172.1                      312.02
# 2022-10-31                      0.0                      290.03
# 2022-11-30                      0.0                      146.37

# %%
# Instantiating empty dataframe

df2 = pd.DataFrame({})

# Reading energy cost data into memory

df3 = pd.read_csv('../../data/raw/energy-costs.csv')[1:-1]

# Define billing start dates

start_dates = df3['Billing Period Start'].to_list()

# and billing end dates

end_dates = df3['Billing Period End'].to_list()

# Zipping them together into a list of tuples

dates = list(zip(start_dates, end_dates))

# %%
dates[0]
# Out:
# ('11/17/2021', '12/17/2021')

# %%
# Hacky way to reample the data based on the billing periods
# of irregular durations, with the ultimate goal of merging this dataframe
# with our `energy costs` dataframe

for i in range(len(dates)):
    
    # Yes, this is ugly and could be written better
    
    start_date = dates[i][0].split('/')[2] + '-' + dates[i][0].split('/')[0] + '-' + dates[i][0].split('/')[1]
    end_date = dates[i][1].split('/')[2] + '-' + dates[i][1].split('/')[0] + '-' + dates[i][1].split('/')[1]
    
    # Iteratively appending resampled rows to previously-empty dataframe
    
    df2 = df2.append(df.loc[start_date : end_date].sum().to_frame().T, ignore_index=True)

# %%
# Creating new columns

df2['Billing Period Duration'] = pd.to_datetime(pd.to_datetime(pd.Series(end_dates))) - pd.to_datetime(pd.to_datetime(pd.Series(start_dates)))
df2['Billing Period Start'] = pd.Series(start_dates)
df2['Billing Period End'] = pd.Series(end_dates)

# %%
# Taking a peek

df2
# Out:
#     Solar Energy (kWh)  Inverter 1 Energy (kWh)  Inverter 2 Energy (kWh)  \
# 0                590.2                    282.2                    307.8
# 1                366.8                     77.1                    289.7
# 2                738.0                    355.5                    382.6
# 3               1280.5                    608.4                    672.1
# 4               1323.8                    641.0                    682.7
# 5               1511.0                    736.2                    775.2
# 6               1546.6                    752.0                    794.8
# 7               1594.7                    775.0                    819.6
# 8               1123.7                    547.8                    576.0
# 9               1108.3                    622.9                    485.2
# 10               482.5                    482.5                      0.0
# 11               285.4                    285.4                      0.0
#
#     Daylength in decimal hours Billing Period Duration Billing Period Start  \
# 0                       251.94                 30 days           11/17/2021
# 1                       266.70                 32 days           12/18/2021
# 2                       244.05                 27 days            1/20/2022
# 3                       320.33                 32 days            2/17/2022
# 4                       312.83                 28 days            3/22/2022
# 5                       339.47                 28 days            4/20/2022
# 6                       369.80                 29 days            5/19/2022
# 7                       395.68                 31 days            6/18/2022
# 8                       330.32                 27 days            7/20/2022
# 9                       368.61                 33 days            8/17/2022
# 10                      273.81                 27 days            9/20/2022
# 11                      273.39                 30 days           10/18/2022
#
#    Billing Period End
# 0          12/17/2021
# 1           1/19/2022
# 2           2/16/2022
# 3           3/21/2022
# 4           4/19/2022
# 5           5/18/2022
# 6           6/17/2022
# 7           7/19/2022
# 8           8/16/2022
# 9           9/19/2022
# 10         10/17/2022
# 11         11/17/2022

# %%
# Spot check

df.loc['2021-11-17':'2021-12-17'].sum()
# Out:
# Solar Energy (kWh)            590.20
# Inverter 1 Energy (kWh)       282.20
# Inverter 2 Energy (kWh)       307.80
# Daylength in decimal hours    251.94
# dtype: float64

# %%
# Well would ya look at that! It worked!

df4 = df2.merge(df3)
df4
# Out:
#     Solar Energy (kWh)  Inverter 1 Energy (kWh)  Inverter 2 Energy (kWh)  \
# 0                590.2                    282.2                    307.8
# 1                366.8                     77.1                    289.7
# 2                738.0                    355.5                    382.6
# 3               1280.5                    608.4                    672.1
# 4               1323.8                    641.0                    682.7
# 5               1511.0                    736.2                    775.2
# 6               1546.6                    752.0                    794.8
# 7               1594.7                    775.0                    819.6
# 8               1123.7                    547.8                    576.0
# 9               1108.3                    622.9                    485.2
# 10               482.5                    482.5                      0.0
# 11               285.4                    285.4                      0.0
#
#     Daylength in decimal hours Billing Period Duration Billing Period Start  \
# 0                       251.94                 30 days           11/17/2021
# 1                       266.70                 32 days           12/18/2021
# 2                       244.05                 27 days            1/20/2022
# 3                       320.33                 32 days            2/17/2022
# 4                       312.83                 28 days            3/22/2022
# 5                       339.47                 28 days            4/20/2022
# 6                       369.80                 29 days            5/19/2022
# 7                       395.68                 31 days            6/18/2022
# 8                       330.32                 27 days            7/20/2022
# 9                       368.61                 33 days            8/17/2022
# 10                      273.81                 27 days            9/20/2022
# 11                      273.39                 30 days           10/18/2022
#
#    Billing Period End  Net Usage  Net Generation  Billable kWh  ...  \
# 0          12/17/2021       1262             139          1123  ...
# 1           1/19/2022       2090              44          2046  ...
# 2           2/16/2022       1092             263           829  ...
# 3           3/21/2022        834             674           160  ...
# 4           4/19/2022       1068             595           473  ...
# 5           5/18/2022       1027             675           352  ...
# 6           6/17/2022       1380             498           882  ...
# 7           7/19/2022       1808             398          1410  ...
# 8           8/16/2022       1700             252          1448  ...
# 9           9/19/2022       1973             318          1655  ...
# 10         10/17/2022        922             265           657  ...
# 11         11/17/2022       1225             110          1115  ...
#
#     Usage Charge  Subtotal after Adjustments  \
# 0         131.28                      189.39
# 1         239.18                      337.16
# 2          96.91                      142.32
# 3          18.70                       35.22
# 4          55.29                       85.33
# 5          41.15                       60.15
# 6         103.11                      129.20
# 7         164.83                      200.80
# 8         169.27                      205.95
# 9         193.47                      252.72
# 10         76.80                      117.28
# 11        130.34                      193.02
#
#     Non-Renewable Adjustment per kWh  Renewable Adjustment per kWh  \
# 0                             0.0218                        0.0214
# 1                             0.0215                        0.0217
# 2                             0.0218                        0.0214
# 3                             0.0227                        0.0205
# 4                             0.0239                        0.0193
# 5                             0.0086                        0.0181
# 6                             0.0015                        0.0172
# 7                             0.0028                        0.0159
# 8                             0.0057                        0.0130
# 9                             0.0202                        0.0098
# 10                            0.0403                        0.0067
# 11                            0.0433                        0.0043
#
#     Total Adjustment per kWh  Public Benefits Charge per KwH  \
# 0                     0.0432                          0.0285
# 1                     0.0432                          0.0285
# 2                     0.0432                          0.0285
# 3                     0.0432                          0.0285
# 4                     0.0432                          0.0285
# 5                     0.0267                          0.0285
# 6                     0.0187                          0.0285
# 7                     0.0187                          0.0285
# 8                     0.0187                          0.0285
# 9                     0.0300                          0.0285
# 10                    0.0470                          0.0285
# 11                    0.0476                          0.0285
#
#     Public Benefits Charge  California Energy Surcharge per KwH  \
# 0                     5.40                               0.0003
# 1                     9.61                               0.0003
# 2                     4.06                               0.0003
# 3                     1.00                               0.0003
# 4                     2.43                               0.0003
# 5                     1.71                               0.0003
# 6                     3.68                               0.0003
# 7                     5.72                               0.0003
# 8                     5.87                               0.0003
# 9                     7.20                               0.0003
# 10                    3.34                               0.0003
# 11                    5.50                               0.0003
#
#     California Energy Surcharge  Total Charge
# 0                          0.34        195.13
# 1                          0.61        347.39
# 2                          0.25        146.63
# 3                          0.05         36.27
# 4                          0.14         87.90
# 5                          0.11         61.97
# 6                          0.26        133.15
# 7                          0.42        206.94
# 8                          0.43        212.25
# 9                          0.50        260.42
# 10                         0.20        120.82
# 11                         0.33        198.85
#
# [12 rows x 22 columns]

# %%
# Exporting CSV for downstream processing

df4.to_csv('../../data/processed/resampled_merged_data.csv')
