# %%
# Importing dependencies

import pandas as pd

# %% [markdown]
# This data was painstakingly extracted from our power bills and entered into a spreadsheet...fun stuff!
#
# <img src = 'https://raw.githubusercontent.com/nickmccarty/solar-energy-predictor/main/images/power-bill-screenshot.jpg' width = '500px'>

# %%
# Reading data into memory

df = pd.read_csv('../../data/raw/energy-costs.csv')[1:-1]

# Taking a peek, no processing needed at this time

df
# Out:
#    Billing Period Start Billing Period End  Net Usage  Net Generation  \
# 1            11/17/2021         12/17/2021       1262             139
# 2            12/18/2021          1/19/2022       2090              44
# 3             1/20/2022          2/16/2022       1092             263
# 4             2/17/2022          3/21/2022        834             674
# 5             3/22/2022          4/19/2022       1068             595
# 6             4/20/2022          5/18/2022       1027             675
# 7             5/19/2022          6/17/2022       1380             498
# 8             6/18/2022          7/19/2022       1808             398
# 9             7/20/2022          8/16/2022       1700             252
# 10            8/17/2022          9/19/2022       1973             318
# 11            9/20/2022         10/17/2022        922             265
# 12           10/18/2022         11/17/2022       1225             110
#
# ...
