# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/interim/combined-solar-data.csv', index_col = 0).set_index('Date time')

# %%
df.loc['2021-11-17':]
# Out:
#                            Solar Energy (kWh)  \
# Date time
# 2021-11-17 01:00:00-08:00                22.8
# 2021-11-18 01:00:00-08:00                22.0
# 2021-11-19 01:00:00-08:00                20.4
# 2021-11-20 01:00:00-08:00                21.3
# 2021-11-21 01:00:00-08:00                22.8
# ...                                       ...
# 2022-11-13 01:00:00-08:07                 0.0
# 2022-11-14 01:00:00-08:08                 0.0
# 2022-11-15 01:00:00-08:09                 0.0
# 2022-11-16 01:00:00-08:10                 0.0
# 2022-11-17 01:00:00-08:10                 0.0
#
#                            Inverter 5441d581-c9d9-4e00-a7c9-f8a9b45ec456 Energy (kWh)  \
# Date time
# 2021-11-17 01:00:00-08:00                                               10.9
# 2021-11-18 01:00:00-08:00                                               10.6
# 2021-11-19 01:00:00-08:00                                                9.9
# ...
