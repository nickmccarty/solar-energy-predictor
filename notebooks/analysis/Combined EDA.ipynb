# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/processed/solar_and_daylength_data.csv', index_col = 0)

# %%
df
# Out:
#             Solar Energy (kWh)  Inverter 1 Energy (kWh)  \
# Date
# 2021-11-17                22.8                     10.9
# 2021-11-18                22.0                     10.6
# 2021-11-19                20.4                      9.9
# 2021-11-20                21.3                     10.2
# 2021-11-21                22.8                     10.8
# ...                        ...                      ...
# 2022-11-13                 0.0                      0.0
# 2022-11-14                 0.0                      0.0
# 2022-11-15                 0.0                      0.0
# 2022-11-16                 0.0                      0.0
# 2022-11-17                 0.0                      0.0
#
#             Inverter 1 Lifetime Cumulative Energy (kWh)  \
# Date
# 2021-11-17                                      40524.1
# 2021-11-18                                      40534.7
# 2021-11-19                                      40544.6
# ...
