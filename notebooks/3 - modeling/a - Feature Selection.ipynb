# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/processed/resampled_merged_data.csv', index_col = 0)

# %%
df
# Out:
#     Solar Energy (kWh)  Inverter 1 Energy (kWh)  Inverter 2 Energy (kWh)  \
# 0                590.2                    282.2                    307.8
# 1                366.8                     77.1                    289.7
# 2                738.0                    355.5                    382.6
# 3               1280.5                    608.4                    672.1
# 4               1323.8                    641.0                    682.7
# 5               1511.0                    736.2                    775.2
# 6               1546.6                    752.0                    794.8
# 7               1594.7                    775.0                    819.6
# 8               1123.7                    547.8                    576.0
# 9               1108.3                    622.9                    485.2
# 10               482.5                    482.5                      0.0
# 11               285.4                    285.4                      0.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Solar Energy (kWh)                   12 non-null     float64
#  1   Inverter 1 Energy (kWh)              12 non-null     float64
#  2   Inverter 2 Energy (kWh)              12 non-null     float64
#  3   Daylength in decimal hours           12 non-null     float64
#  4   Billing Period Duration              12 non-null     object
#  5   Billing Period Start                 12 non-null     object
#  6   Billing Period End                   12 non-null     object
#  7   Net Usage                            12 non-null     int64
#  8   Net Generation                       12 non-null     int64
#  9   Billable kWh                         12 non-null     int64
#  10  Customer Charge                      12 non-null     float64
# ...

# %%
features = ['Solar Energy (kWh)',
            'Inverter 1 Energy (kWh)',
            'Inverter 2 Energy (kWh)',
            'Daylength in decimal hours',
            'Billing Period Duration',
            'Net Usage',
            'Net Generation',
            'Billable kWh',
            'Usage Charge',
            'Total Adjustment per kWh',
            'Total Charge']

df[features].to_csv('../../data/processed/selected_features.csv')
